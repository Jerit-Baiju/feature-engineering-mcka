# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create a DataFrame
data = {
    "Height": [172, 158, 180, 165, 175, 160, 178, 162],
    "Weight": [70, 55, 80, 60, 75, 50, 77, 58],
    "Age": [25, 22, 30, 21, 28, 20, 29, 23],
    "Score": [88, 75, 92, 70, 85, 65, 90, 72],
}

df = pd.DataFrame(data)

# Step 2: Compute correlation matrix
corr_matrix = df.corr()

# Step 3: Visualize correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation matrix:
#           Height    Weight       Age     Score
# Height  1.000000  0.981166  0.939112  0.906887
# Weight  0.981166  1.000000  0.966281  0.948662
# Age     0.939112  0.966281  1.000000  0.936672
# Score   0.906887  0.948662  0.936672  1.000000
